# %% [markdown]
# <a href="https://colab.research.google.com/github/JFish72/CSC-349-Machine-Learning-/blob/main/HW2/HW2(Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?
#   - Overall, it wasn't that challenging. I downloaded the zip file with the .csv file in it to my local computer and then added it to my Google Colab files under sample_data. I did notice how each time I returned to my Google Colab file through GitHub, I had to re-enter the .csv file back under sample_data. When examining the data, there seemed to be more work that had to go into preparing the data for the assignment compared to previous examples using data that was ready for use.
# 2.   How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
#   - Using the .info() method, I noticed immediately that the encryption_used column was missing data as the non-null count was 7571 compared to all other columns with a non-null count of 9537. I decided to replace these null values with the mode since encryption type is a categorical value. This solved my problems as I didn't want to lose valuable data, but I also couldn't study the data with null values in place.
# 3.   Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across Preprocessing steps.
#   - It allowed me to apply different preprocessing to the catergorical columns (OneHotEncoder) and the numerical columns separately (StandardScaler). The Pipeline then made it so I could bring the processes together and data can be directly split into a training set and a testing set. This prevents data from the test influencing the data in the training set.
# 4.   Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal?
#   - failed_logins (0.36) and login_attempts (0.28) had the strongest positive relationships. This means that the large numbers of failed logins could be a sign of a cyberattack, most likely a brute-force method. For operational insights this could mean that IT departments must monitor failed_logins and login_attempts to better anticipate cyberattacks.
