# %% [markdown]
# <a href="https://colab.research.google.com/github/JFish72/CSC-349-Machine-Learning-/blob/main/HW1/Notebook_1_Python_Essentials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Essentials for Machine Learning
# This notebook introduces basic Python skills needed for machine learning in this course.

# %%
x = 5
y = 3.14
name = 'Alice'
print(x, y, name)
# Out:
# 5 3.14 Alice

# %%
age = 20
major = 'Data Science'
print(age)
print(major)
# Out:
# 20
# Data Science

# %% [markdown]
# ## Lists

# %%
grades = [88, 91, 76, 95]
print(sum(grades)/len(grades))
# Out:
# 87.5

# %% [markdown]
# ## Dictionaries

# %%
student = {'name': 'Alice', 'major': 'CS', 'gpa': 3.8}
for key, value in student.items():
    print(key, value)
# Out:
# name Alice
# major CS
# gpa 3.8

# %% [markdown]
# ## Functions

# %%
def square(x):
    return x * x

print(square(5))
# Out:
# 25
