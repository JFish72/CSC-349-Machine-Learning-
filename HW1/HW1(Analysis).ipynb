# %% [markdown]
# <a href="https://colab.research.google.com/github/JFish72/CSC-349-Machine-Learning-/blob/main/HW1/HW1(Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.  Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
#   Google Colab should be treated as your sandbox or area to write and design your code. Colab allows you to upload notebooks that you've downloaded from GitHub, which allows you to run other people's programs. Managing files from Google Colab to GitHub is also easy as you can save a copy directly to a branch in your repository.
#
#
# ---
#
#
# 2.   Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
#   All of my notebooks executed successfully; however, I had to be sure to run the blocks of code in order as certain import statements were required for the lower blocks to run without errors.
#
# ---
#
#
# 3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
#   Using GitHubs web interface, I created a seperate repository with individual files for each homework. This allows me to organize my work more clearly, especially when moving files from Google Colab to GitHub
#
# ---
#
#
# 4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
#   Python is the most important backbone of machine learning. Without understanding Python data strucutrues and the libraries behind them, we cannot create useful and meaningful machine learning algorithms. These tools not only make creating machine learning algorithms easier for us, but also make them more efficient and accurate.
