# %% [markdown]
# <a href="https://colab.research.google.com/github/JFish72/CSC-349-Machine-Learning-/blob/main/HW3/HW3(Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets, specifically regarding implicit data types like whitespace entries in TotalCharges?
#   - The data had to be examined in multiple ways before I could continue my work on the data. This meant making rolling adjustments to the data. When it came to dealing with the white space, I noticed that TotalCharges was being treated as an object rather than a float category; therefore I had to replace the whitespace values with NaN and then fill the values with the median using the SimpleImputer.
#
# 2. How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
#   - I simply looked at the results from df.info() and df.isnull(). Any value with NaN was replaced using the SimpleImputer for numeric (Replaces the space with the median of the data) and the OneHotEncoder for categorical data (Replaces the missing value with the mode of the data).
#
# 3. Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing and training steps.
#   - It allows me to separate the preprocessing by catergorical columns and numerical columns. I can then use the OneHotEncoder on just my categorical columns and the StandardScaler for numeric columns. The pipeline prevents data leakage by ensuring that scaler, encoder, and imputer learn from the training data only. Therefore, we can still accuralty test the model.
#
# 4. How did comparing StandardScaler versus MinMaxScaler impact your model training, convergence, or final evaluation metrics?
#   - TheMinMaxScaler slighlty increased the accuracy and precsiosn of my model, but the StandardScaler improved recall and F1-Score. For my model, I chose the StandardScaler, as having better recall is better at seeing how many customers are actually churned.
#
# 5. How does configuring SGDClassifier(loss='log_loss') differ from standard linear classification models, and what advantages do probability outputs and ROC-AUC metrics provide when evaluating customer churn?
#   - With an SGDClassifier (loss='log_loss '), the model produces the probability behind a customer being either churned or not rather than simply saying yes or no. ROC-AUC metrics demonstrate how the model can choose between classifying a customer as churned or retained across the different thresholds.
#
# 6. Based on your model coefficients or feature evaluation, which features show the strongest relationship with customer churn, and what operational business insights do these findings reveal?
#   - Based on my model coefficients, I have determined that fiber optic services and month-to-month billing have the strongest positive relationship with churn, which means they are pushing customers to leave. In order to try and keep customers, I would suggest for the company to promote cheaper rates for signing a year long contract. Fiber optic is also a very expensive service with many other competitors offering cheaper rates at times.
